# %% [markdown]
# # betelbot
#
# This notebook is a modified version of code from [betelbot](https://github.com/hippke/betelbot) by Michael Hippke.
#
# Copyright 2020 Allen Downey
# [MIT License](https://opensource.org/licenses/MIT)

# %%
import datetime

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import requests
from bs4 import BeautifulSoup

from astropy.stats import biweight_location

# %%
def get_mags_from_AAVSO(url, params):
    """Read a table from AAVSO.
    
    url: base URL
    params: dictionary of parameters
    
    returns: DataFrame
    """
    r = requests.get(url, params=params)
    print(r.url)
    soup = BeautifulSoup(r.content, 'html.parser')
    
    # make the dataframe
    columns = ['mag', 'band']
    df = pd.DataFrame(columns=columns, dtype=float)
    
    # read the table rows
    rows = soup.select('tr')
    for row in rows:
        string = '' + row.text
        t = string.split('\n')
        if len(t) == 12:
            date = float(t[3])
            mag = float(t[5])
            band = t[7]
            df.loc[date] = mag, band
            
    return df

# %%
from astropy.time import Time
nt = Time.now()

end = nt.jd
start = end - 20

start, end
# Out:
# (2458968.1436887244, 2458988.1436887244)

# %%
# get the CCD magnitudes
url = 'https://www.aavso.org/apps/webobs/results/'

params = {'star': 'betelgeuse',
          'start': start,
          'end': end,
          'num_results': 100,
          'obs_types': 'dslr ccd'}

params = {'star': 'betelgeuse',
          'num_results': 100,
          'obs_types': 'dslr ccd'}

df = get_mags_from_AAVSO(url, params)
len(df)
# Out:
# https://www.aavso.org/apps/webobs/results/?star=betelgeuse&num_results=100&obs_types=dslr+ccd
# 63

# %%
df.head()
# Out:
#                 mag band
# 2.458965e+06  0.983   TB
# 2.458964e+06  1.502   TB
# 2.458963e+06  0.456    V
# 2.458963e+06  0.409    V
# 2.458963e+06  0.410    V

# %%
df['mag'].plot()

# %%
def get_recent_mag(df, days):
    """Select recent measurements.
    
    df: DataFrame
    days: number of days to collect

    returns: Series of magnitudes
    """
    mags = df['mag'].copy()
    mags.index -= mags.index.max()
    recent = (mags.index >= -days)
    return mags[recent]

# %% [markdown]
# Select recent measurements with band V (visible light?)

# %%
band_v = (df['band'] == 'V')
ccd_obs = get_recent_mag(df[band_v], 20)

# %% [markdown]
# The following function uses LOWESS to smooth the timeseries.

# %%
from statsmodels.nonparametric.smoothers_lowess import lowess

def make_lowess(series):
    """Use LOWESS to compute a smooth line.
    
    series: pd.Series
    
    returns: pd.Series
    """
    y = series.values
    x = series.index.values

    smooth = lowess(y, x)
    index, data = np.transpose(smooth)

    return pd.Series(data, index=index)

# %%
def decorate():
    """Add labels to the axes.
    """
    plt.xlabel('Days before today')
    plt.ylabel('Visual magnitude')

    mid = 1.0
    plt.ylim(mid-1, mid+1)
    
    # why are we inverting the y axis?
    plt.gca().invert_yaxis()

# %% [markdown]
# Plot the CCD data

# %%
ccd_obs.plot(style='o', markersize=4, alpha=0.3)

smooth = make_lowess(ccd_obs)
smooth.plot(color='C0', alpha=0.5)

decorate()

# %% [markdown]
# ## Visual data

# %% [markdown]
# https://www.aavso.org/apps/webobs/results/?start=2458965&end=2458970&num_results=25&obs_types=all&star=betelgeuse

# %%
url = 'https://www.aavso.org/apps/webobs/results/'

params = {'star': 'betelgeuse',
          'start': start,
          'end': end,
          'num_results': 1000,
          'obs_types': 'dslr vis',
          'page': 1}

vis = get_mags_from_AAVSO(url, params)
len(vis)
# Out:
# https://www.aavso.org/apps/webobs/results/?star=betelgeuse&start=2458968.1436887244&end=2458988.1436887244&num_results=1000&obs_types=dslr+vis&page=1
# 35

# %%
vis_mag = vis['mag'].copy()
vis_mag.index -= vis_mag.index.max()

# %%
vis_mag.plot(style='o', markersize=4, alpha=0.3)

smooth = make_lowess(vis_mag)
smooth.plot(color='C0', alpha=0.5)

decorate()

# %%
def make_plot(ccd_obs, vis_obs):
    """
    """

    smooth = make_lowess(vis_obs)
    smooth.plot(color='C0', alpha=0.5)

    vis_obs.plot(style='o', markersize=4, alpha=0.3)
    ccd_obs.plot(style='o', markersize=4, alpha=0.3)

    decorate()

# %%
make_plot(ccd_obs20, vis_mag)

# %%
date_text = datetime.datetime.now().strftime("%d %b %Y")
date_text
# Out:
# '18 May 2020'

# %%
last24hrs = (vis_mag.index >= -1)
data = vis_mag[last24hrs]
mean_last24hrs = biweight_location(data)
mean_last24hrs
# Out:
# 0.53

# %%
lumi = str(format(mean_last24hrs, '.2f'))
lumi
# Out:
# '0.53'

# %%
s = f'#Betelgeuse brightness {lumi} mag on {date_text} by @betelbot'
s
# Out:
# '#Betelgeuse brightness 0.53 mag on 18 May 2020 by @betelbot'

# %%
def build_string(days_ago, mag):
    print('Building string...')
    data_last24hrs = np.where(days_ago<1)
    data_last1_6_days = np.where((days_ago<6) & (days_ago>1))
    n_obs_last24hrs = np.size(mag[data_last24hrs])
    n_obs_last1_6_days = np.size(mag[data_last1_6_days])
    mean_last24hrs = biweight_location(mag[data_last24hrs])
    mean_last1_6_days = biweight_location(mag[data_last1_6_days])
    stdev = np.std(mag[data_last24hrs]) / np.sqrt(n_obs_last24hrs) \
        + np.std(mag[data_last1_6_days]) / np.sqrt(n_obs_last1_6_days)
    diff = mean_last24hrs - mean_last1_6_days
    sigma = diff / stdev

    if n_obs_last24hrs < 1 or n_obs_last1_6_days < 2:
        print('Not enough observations. Abort.')
        return None
    else:

        if diff > 0:
            changeword = 'dimmer'
        else:
            changeword = 'brighter'

        mag_text = "My visual mag from last night was " + \
            str(format(mean_last24hrs, '.2f')) + \
            ' (robust mean of ' + \
            str(n_obs_last24hrs) + \
            ' observations). '

        change_text = 'That is ' + \
            format(abs(diff), '.2f') + \
            ' mag ' + \
            changeword + \
            ' than the robust mean of the 5 previous nights (n=' + \
            str(n_obs_last1_6_days) + \
            ', ' + \
            format(abs(sigma), '.1f') + \
            'σ). #Betelgeuse'

        text = mag_text + change_text
        print(text)
        return text

# %% [markdown]
# ## Use pandas.read_html?
#
# Pandas can parse the HTML and make a DataFrame, but the result is kind of a mess.  We're probably better off with BeautifulSoup.

# %%
url = 'https://www.aavso.org/apps/webobs/results/'

params = {'star': 'betelgeuse',
          'num_results': 200,
          'obs_types': 'dslr ptg pep ccd visdig',
          'page': 1}

# %%
import requests

r = requests.get(url, params=params)

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html lang=\'en\'>\n  <head>\n    \n    <title>AAVSO -- WebObs Search Results</title>\n    <meta http-equiv="Content-Type" content=\'text/html; charset=utf-8\' />\n\n    <!-- css includes -->\n    \n\n      <link href="/static/compressed/css/base.ba6c58564962.css" rel="stylesheet" type="text/css" media="screen" />\n      <link href="/static/compressed/css/print.b055ce91ad2d.css" rel="stylesheet" type="text/css" media="print" />\n    \n<style type="text/css">\np#obsinfo {\n    font-weight: bold;\n    font-size: 1.1em;\n}\n#obsinfo strong {\n    font-weight: bold;\n    font-style: italic;\n    color: green;\n}\n</style>\n\n\n    <!-- js includes -->\n    \n\n      <script type="text/javascript" src="/static/compressed/js/base.3f50618b9299.js" charset="utf-8"></script>\n    \n<script type="text/javascript" src="/static/compressed/js/webobs.5a9abd7df356.js" charset="utf-8"></script>\n\n\n    <!-- Google Analytics Tag -->\n    <script>\n(function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\nm=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n})(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\nga(\'create\', \'UA-12783302-1\', \'auto\');\nga(\'send\', \'pageview\');\n    </script>\n  </head>\n\n  <body>\n    <div class=\'container\'>\n      <div class=\'row\'>\n        <header class=\'col-lg-12\'>\n        <a href=\'#\'>\n          <img src=\'/static/img/header.png\' class=\'img-responsive\'\n            alt=\'AAVSO: American Association of Variable Star Observers\' />\n        </a>\n        </header>\n      </div>\n\n      \n\n\n      \n      \n      \n\n\n\n\n\n\n      <ol class=\'breadcrumb\'>\n<li><a href=\'/\'>Home</a></li><li><a href=\'/webobs/\'>WebObs</a></li><li><a href=\'/apps/webobs/search/\'>Search</a></li><li class=\'active\'>Results</li>\n</ol>\n\n\n      \n      \n      <!-- Messages -->\n\n\n      \n\n      <div class=\'row\'>\n        \n        <div class=\'col-lg-12\'>\n          <h1>WebObs Search Results</h1>\n        </div>\n      </div>\n\n      <div class=\'row\'>\n        <div class=\'col-lg-12\'>\n          \n\n\n  \n  <p id=\'obsinfo\'>Showing <strong>2,779</strong>\n  observations\n  \n  for <strong>alf Ori</strong>\n  \n  \n  \n  from <strong>86</strong> observers\n  \n  \n  \n  \n  </p>\n\n  \n  <ul class="links">\n    <li><a href="/vsp">Plot a Chart</a></li>\n    <li><a href="/LCGv2/">Generate a Light Curve</a></li>\n    <li><a href="http://www.aavso.org/vsx/index.php?view=search.top">Search VSX</a></li>\n  </ul>\n\n  \n  \n<table class=\'observations\'>\n  <thead>\n    <tr>\n      \n      <th class=\'empty\' colspan=\'3\'></th>\n      \n      <th>Star</th>\n      <th>JD</th>\n      <th>Calendar Date</th>\n      <th>Magnitude</th>\n      <th>Error</th>\n      <th>Filter</th>\n      <th>Observer</th>\n      <th class=\'empty\' id=\'expand-all\'></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr class=\'obs tr-even\' id=\'ob-0\'>\n  \n  \n  <td class=\'empty\' colspan=\'3\'></td>\n  \n\n  <td>BETELGEUSE</td>\n  <td>2458965.16949</td>\n  <td>2020 Apr. 25.66949</td>\n  \n  <td><a target=\'_blank\' href=\'https://aavso.org/lcgv2/index.htm?DateFormat=Julian&amp;RequestedBands=&amp;view=api.delim&amp;ident=000-BBK-383&amp;fromjd=2458865.16949&amp;tojd=2459065.16949&amp;delimiter=%40%40%40\'\n      >-0.314</a></td>\n  \n  <td>0.003</td>\n  <td>TR</td>\n  <td>OAAA</td>\n  <td><a href=\'#\' class=\'obs-link\' id=\'ob-0\'>Details...</a>\n  </td>\n</tr>\n\n\n<tr id=\'ob-0-detail\' class=\'obs-detail-tr\'>\n  <td colspan=\'11\'>\n    <div id=\'ob-0-detail-div\' class=\'obs-detail-div\'>\n    <table class=\'obs-detail\'>\n      <thead>\n        <tr>\n          \n          <th>Comp Star</th>\n          <th>Check Star</th>\n          <th>Transformed</th>\n          <th>Chart</th>\n          <th>Comment Codes</th>\n          <th>Notes</th>\n  ...

# %%
import pandas as pd
tables = pd.read_html(r.text)

# %%
len(tables)
# Out:
# 201

# %%
table = tables[0]
table.columns
# Out:
# MultiIndex([( 'Unnamed: 0_level_0',           'Comp Star', ...),
#             ( 'Unnamed: 1_level_0',          'Check Star', ...),
#             ( 'Unnamed: 2_level_0',         'Transformed', ...),
#             (               'Star',               'Chart', ...),
#             (                 'JD',       'Comment Codes', ...),
#             (      'Calendar Date',               'Notes', ...),
#             (          'Magnitude',  'Unnamed: 6_level_1', ...),
#             (              'Error',  'Unnamed: 7_level_1', ...),
#             (             'Filter',  'Unnamed: 8_level_1', ...),
#             (           'Observer',  'Unnamed: 9_level_1', ...),
#             ('Unnamed: 10_level_0', 'Unnamed: 10_level_1', ...)],
#            )

# %% [markdown]
# ## Use the API
#
# Using the API and getting JSON would be better than parsing HTML, but it looks like the API works with a different dataset.

# %%
url = 'https://www.aavso.org/apps/vsp/api/chart/'

# %%
params = {'format': 'json',
          'star': 'SS Cyg',
          'fov': 60,
          'maglimit': 14.5}

# %%
params = {'format': 'json',
          'star': 'Alf Ori',
          'fov': 60,
          'maglimit': 0.01}

# %%
import requests

r = requests.get(url, params=params)

# %%
r.url
# Out:
# 'https://www.aavso.org/apps/vsp/api/chart/?format=json&star=Alf+Ori&fov=60&maglimit=0.01'

# %%
json = r.json()
json
# Out:
# {'comment': '',
#  'star': 'Alf Ori',
#  'maglimit': 0.01,
#  'special': None,
#  'auid': '000-BBK-383',
#  'fov': 60.0,
#  'dec': '07:24:25.4',
#  'title': '',
#  'dss': False,
#  'chartid': 'X25374CK',
#  'image_uri': 'https://www.aavso.org/apps/vsp/chart/X25374CK.png',
#  'ra': '05:55:10.30',
#  'photometry': [],
#  'resolution': 150}

# %%
pd.read_json(r.text)
# Out:
# Empty DataFrame
# Columns: [comment, star, maglimit, special, auid, fov, dec, title, dss, chartid, image_uri, ra, photometry, resolution]
# Index: []
